# %%
import pandas as pd

# %%
unmatched = pd.read_csv('/media/johnattan/LaCie/Twitter_Terms/ALCOHOL/2020-6.csv')
matched = pd.read_csv('/media/johnattan/LaCie/Twitter_Terms/ALCOHOL/GEO-Tweets.csv')

# %%
unmatched.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0  1267244471277760513
# 1           1  1267244894915002373
# 2           2  1267244929320919041
# 3           3  1267245217821982720
# 4           4  1267245262210244608
#
#                                                 text  \
# 0  As the country looks to bounce back from the p...
# 1  🏭 We’ve diverted resources to make isopropyl a...
# 2  As the country looks to bounce back from the p...
# 3  Coronavirus cases is near 2 million in the US ...
# 4  Coronavirus cases is near 2 million in the US ...
#
#                   created_at  \
# 0  2020-06-01 00:00:00+00:00
# 1  2020-06-01 00:01:41+00:00
# 2  2020-06-01 00:01:50+00:00
# 3  2020-06-01 00:02:58+00:00
# 4  2020-06-01 00:03:09+00:00
#
#                                                 urls profile_location  \
# 0  ['https://twitter.com/i/web/status/12672444712...    Baltimore, MD
# 1  ['https://twitter.com/i/web/status/12638328504...            കേരളം
# 2  ['https://twitter.com/i/web/status/12672444712...        Maryland
# 3  ['https://twitter.com/i/web/status/12672428215...         𝙖𝙞𝙧𝙥𝙡𝙖𝙣𝙚
# 4  ['https://twitter.com/i/web/status/12672428215...    bffies :P ||
#
#   geotag_location geotag_country
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
matched.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            id  \
# 0           0             0  1.215713e+18
# 1           1             1  1.217161e+18
# 2           2             3  1.217169e+18
# 3           3             9  1.217170e+18
# 4           4            15  1.217170e+18
#
#                                                 text  \
# 0  Jan. 10 news: Alcohol deaths double, new coron...
# 1  Jan. 14 News: Air in Australia posed a threat ...
# 2  How to handwash? Use 🧼 and water for at least ...
# 3  How to handwash? Use 🧼 and water for at least ...
# 4  How to handwash? Use 🧼 and water for at least ...
#
#                   created_at state
# 0  2020-01-10 19:11:32+00:00    NY
# 1  2020-01-14 19:06:03+00:00    NY
# 2  2020-01-14 19:38:09+00:00    NJ
# 3  2020-01-14 19:40:43+00:00    NY
# 4  2020-01-14 19:42:09+00:00    NY

# %%
unmatched.index[unmatched.created_at == '2020-06-01 00:00:00+00:00']
# Out:
# [0]

# %%
matched.iloc[1121].values
# Out:
# array([1121, 0, 1.2672444712777605e+18,
#        'As the country looks to bounce back from the pandemic, some state leaders say more permanent alcohol-on-demand laws could be the fuel that the restaurant and service industry needs to restart their economies. https://t.co/2FbP06AQ0E',
#        '2020-06-01 00:00:00+00:00', 'MD'], dtype=object)

# %% [markdown]
# # OK we have the indexes where both meet at June 1st, 2020, now we'll check 100 of em

# %%
base = 1121 + 20
matched.iloc[base:(base + 10)].head(50)
# Out:
#       Unnamed: 0  Unnamed: 0.1            id  \
# 1141        1141           149  1.267308e+18
# 1142        1142           179  1.267318e+18
# 1143        1143           185  1.267319e+18
# 1144        1144           186  1.267319e+18
# 1145        1145           188  1.267319e+18
# 1146        1146           190  1.267319e+18
# 1147        1147           194  1.267320e+18
# 1148        1148           201  1.267320e+18
# 1149        1149           202  1.267320e+18
# 1150        1150           206  1.267321e+18
#
#                                                    text  \
# 1141  The latest Daily Sanitizer News! https://t.co/...
# 1142  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1143  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1144  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1145  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1146  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1147  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1148  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1149  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 1150  DEMOCRATS LAST WEEK: It’s ok if you die from s...
#
#                      created_at state
# 1141  2020-06-01 04:11:01+00:00    CA
# 1142  2020-06-01 04:52:57+00:00    CA
# 1143  2020-06-01 04:55:32+00:00    PA
# 1144  2020-06-01 04:55:37+00:00    MI
# 1145  2020-06-01 04:56:04+00:00    PA
# 1146  2020-06-01 04:57:23+00:00    CA
# 1147  2020-06-01 05:00:04+00:00    TX
# 1148  2020-06-01 05:01:27+00:00    CA
# 1149  2020-06-01 05:01:56+00:00    AL
# 1150  2020-06-01 05:03:24+00:00    CA

# %%
base = 200
unmatched.iloc[base:(base + 10)].head(50)
# Out:
#      Unnamed: 0                   id  \
# 200         200  1267320314649772040
# 201         201  1267320332815413248
# 202         202  1267320452768321536
# 203         203  1267320558393397250
# 204         204  1267320607915544577
# 205         205  1267320746424127488
# 206         206  1267320823234191360
# 207         207  1267320868692205568
# 208         208  1267320899977576448
# 209         209  1267320995980947462
#
#                                                   text  \
# 200  @DrZweliMkhize minister it's a humble request ...
# 201  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 202  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 203  @DrZweliMkhize minister it's a humble request ...
# 204  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 205  From 9am today, the sale of alcohol will be al...
# 206  DEMOCRATS LAST WEEK: It’s ok if you die from s...
# 207  The weakest part of them is the double envelop...
# 208  @DrZweliMkhize minister it's a humble request ...
# 209  From 9am today, the sale of alcohol will be al...
#
#                     created_at  \
# 200  2020-06-01 05:01:23+00:00
# 201  2020-06-01 05:01:27+00:00
# 202  2020-06-01 05:01:56+00:00
# 203  2020-06-01 05:02:21+00:00
# 204  2020-06-01 05:02:33+00:00
# 205  2020-06-01 05:03:06+00:00
# 206  2020-06-01 05:03:24+00:00
# 207  2020-06-01 05:03:35+00:00
# 208  2020-06-01 05:03:42+00:00
# 209  2020-06-01 05:04:05+00:00
#
#                                                   urls  \
# 200  ['https://twitter.com/i/web/status/12673035444...
# 201  ['https://twitter.com/i/web/status/12673181917...
# 202  ['https://twitter.com/i/web/status/12673181917...
# 203  ['https://twitter.com/i/web/status/12673035444...
# 204  ['https://twitter.com/i/web/status/12673181917...
# 205  ['https://twitter.com/i/web/status/12673207464...
# 206  ['https://twitter.com/i/web/status/12673181917...
# 207  ['https://twitter.com/i/web/status/12673208686...
# 208  ['https://twitter.com/i/web/status/12673035444...
# 209  ['https://twitter.com/i/web/status/12673207464...
#
#             profile_location geotag_location geotag_country
# 200      Mountain Of Paragon             NaN            NaN
# 201          Los Angeles, CA             NaN            NaN
# 202             Alabama, USA             NaN            NaN
# 203                    Kithi             NaN            NaN
# 204                 Colombia             NaN            NaN
# 205             South Africa             NaN            NaN
# 206              Rocklin, CA             NaN            NaN
# 207                  Calicut   Kerala, India             IN
# 208                Newcastle             NaN            NaN
# 209  Milnerton, South Africa             NaN            NaN

# %% [markdown]
# |             | Pred Yes    | Pred No     |
# | ----------- | ----------- | ----------- |
# | Actual No   | 0           | 75          |
# | Actual Yes  | 23          | 2           |

# %%
# Num Wrong
# 2
"""
    - Jersey Shore
    - USA
    - Listed multiple locations picked first one
"""
# Out:
#   File "<ipython-input-66-ca19517a9ab1>", line 9
#     | Syntax      | Description |
#     ^
# SyntaxError: invalid syntax
