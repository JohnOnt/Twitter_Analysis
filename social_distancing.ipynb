# %%
import pandas as pd

# %%
df = pd.read_csv("Train_Data/USstatesCov19distancingpolicy.csv", encoding='latin1')

# %%
df.iloc[0]
# Out:
# location_id                                                            523
# StateFIPS                                                                1
# StatePostal                                                             AL
# StateName                                                          Alabama
# StatePolicy                                                       EmergDec
# Mandate                                                                  1
# StateWide                                                                1
# Curfew                                                                   0
# CurfewStart                                                            NaN
# CurfewEnd                                                              NaN
# VaccineExempt                                                          NaN
# InGathLim                                                              NaN
# ...

# %%
df[(df.StatePostal == 'TX') & (df.StatePolicy == 'BarRestrict')]
# Out:
#       location_id  StateFIPS StatePostal StateName  StatePolicy  Mandate  \
# 1714          566         48          TX     Texas  BarRestrict        1
# 1730          566         48          TX     Texas  BarRestrict        1
# 1731          566         48          TX     Texas  BarRestrict        1
# 1736          566         48          TX     Texas  BarRestrict        1
# 1743          566         48          TX     Texas  BarRestrict        1
#
#       StateWide  Curfew CurfewStart CurfewEnd  ...  DateExpiry   DateEased  \
# 1714          1       0         NaN       NaN  ...  20200604.0  20200522.0
# 1730          0       0         NaN       NaN  ...  20200604.0         NaN
# 1731          1       0         NaN       NaN  ...  20200711.0  20200603.0
# 1736          1       0         NaN       NaN  ...  20201106.0  20201014.0
# 1743          1       0         NaN       NaN  ...  20210405.0         NaN
#
#        DateEnded  DateReexpanded1  DateReeased1  \
# ...
