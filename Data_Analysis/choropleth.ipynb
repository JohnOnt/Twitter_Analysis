# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from choropleth_functions import *

# %%
dates = ['2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12']
dates2 = ['2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12']

# plotty_plots(kw, dates, renderer = 'png', rows = 2, cols = 3, savefig = False):
plotty_plots('WINE', dates2, rows = 4, cols = 3, savefig=True)#, renderer='firefox')

# %%
plotty('WINE', '2020-12')
#plotty_w('WINE', '1')

# %%
build_dataframe('ALCOHOL', ['2020-09'])
# Out:
#    State     Date     Count
# 0     AK  2020-09  0.000947
# 1     AL  2020-09  0.001613
# 2     AR  2020-09  0.001244
# 3     AZ  2020-09  0.001174
# 4     CA  2020-09  0.000855
# 5     CO  2020-09  0.001145
# 6     CT  2020-09  0.000843
# 7     DC  2020-09  0.000463
# 8     DE  2020-09  0.000619
# 9     FL  2020-09  0.001183
# 10    GA  2020-09  0.001090
# 11    HI  2020-09  0.000748
# 12    IA  2020-09  0.001345
# 13    ID  2020-09  0.001468
# 14    IL  2020-09  0.000839
# 15    IN  2020-09  0.001074
# 16    KS  2020-09  0.001246
# 17    KY  2020-09  0.001148
# 18    LA  2020-09  0.001586
# 19    MA  2020-09  0.000851
# 20    MD  2020-09  0.001071
# 21    ME  2020-09  0.001104
# 22    MI  2020-09  0.001130
# 23    MN  2020-09  0.000925
# 24    MO  2020-09  0.001224
# 25    MS  2020-09  0.001414
# 26    MT  2020-09  0.001397
# 27    NC  2020-09  0.001236
# 28    ND  2020-09  0.001285
# 29    NE  2020-09  0.001204
# 30    NH  2020-09  0.000879
# 31    NJ  2020-09  0.001084
# 32    NM  2020-09  0.000896
# 33    NV  2020-09  0.001138
# 34    NY  2020-09  0.000638
# 35    OH  2020-09  0.001361
# 36    OK  2020-09  0.001431
# 37    OR  2020-09  0.000765
# 38    PA  2020-09  0.001403
# 39    RI  2020-09  0.001075
# 40    SC  2020-09  0.001242
# 41    SD  2020-09  0.001051
# 42    TN  2020-09  0.001423
# 43    TX  2020-09  0.001190
# 44    UT  2020-09  0.001200
# 45    VA  2020-09  0.000923
# 46    VT  2020-09  0.000780
# 47    WA  2020-09  0.000731
# 48    WI  2020-09  0.000822
# 49    WV  2020-09  0.001161
# 50    WY  2020-09  0.001147
